# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils.Plotter import Plotter as PL
from utils.ImageExtractor import ImageExtractor as IE
import cv2

# %%
image = cv2.imread("C:/Cours-Sorbonne/M1/Stage/src/data/bd6t5106710b_f14.jpg")
image_smaller = cv2.imread("C:/Cours-Sorbonne/M1/Stage/src/data/bd6t5106710b_f14_S.jpg")
image_extracted = cv2.imread("C:/Cours-Sorbonne/M1/Stage/src/data/similaires_rol_extracted/bd6t5106710b_f14_01_0.996.jpg")
image_extracted2 = cv2.imread("C:/Cours-Sorbonne/M1/Stage/src/data/similaires_rol_extracted/bd6t5106710b_f14_02_0.995.jpg")

# %%
extracted_images_easy = IE.extract(image)

# %%
overlay_image, refined_mask, extracted_images = IE.extract(image_smaller)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
PL.plot_images([image, extracted_images], ["Overlay image", "Extracted"])

# %%
len(extracted_images_easy)
# Out:
# 3

# %%
PL.plot_images([image, extracted_images_easy[2], extracted_images_easy[0], extracted_images_easy[1]], ["Original", "Extracted 1", "Extracted 2", "Extracted 3"], fig_size=(20,17))

# %%
PL.plot_images([image, image_extracted, image_extracted2], ["Original", "Extracted 1", "Extracted 2"], fig_size=(20,17))
